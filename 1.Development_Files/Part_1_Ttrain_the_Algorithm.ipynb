# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# Out:
# /content/gdrive/My Drive/Colab_Notebooks/Ociuz/3.Stress_Detection

# %%
# !ls
# Out:
#  Part_2_Test.ipynb
# 'Stress Detection In IT Professional by Image Processing and Machine Learning.docx'
#  StressPPT.pptx

# %%
# Import necessary libraries

import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
import os
import numpy as np
import argparse
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Prepoare the dataset



# convert string to integer
def atoi(s):
    n = 0
    for i in s:
        n = n*10 + ord(i) - ord("0")
    return n

# making folders
outer_names = ['test','train']
inner_names = ['angry', 'disgusted', 'fearful', 'happy', 'sad', 'surprised', 'neutral']
os.makedirs('data', exist_ok=True)
for outer_name in outer_names:
    os.makedirs(os.path.join('data',outer_name), exist_ok=True)
    for inner_name in inner_names:
        os.makedirs(os.path.join('data',outer_name,inner_name), exist_ok=True)

# to keep count of each category
angry = 0
disgusted = 0
fearful = 0
happy = 0
sad = 0
surprised = 0
neutral = 0
angry_test = 0
disgusted_test = 0
fearful_test = 0
happy_test = 0
sad_test = 0
surprised_test = 0
neutral_test = 0

df = pd.read_csv('./fer2013.csv')
mat = np.zeros((48,48),dtype=np.uint8)
print("Saving images...")

# read the csv file line by line
for i in tqdm(range(len(df))):
    txt = df['pixels'][i]
    words = txt.split()

    # the image size is 48x48
    for j in range(2304):
        xind = j // 48
        yind = j % 48
        mat[xind][yind] = atoi(words[j])

    img = Image.fromarray(mat)

    # train
    if i < 28709:
        if df['emotion'][i] == 0:
            img.save('train/angry/im'+str(angry)+'.png')
            angry += 1
        elif df['emotion'][i] == 1:
            img.save('train/disgusted/im'+str(disgusted)+'.png')
            disgusted += 1
        elif df['emotion'][i] == 2:
            img.save('train/fearful/im'+str(fearful)+'.png')
            fearful += 1
        elif df['emotion'][i] == 3:
            img.save('train/happy/im'+str(happy)+'.png')
            happy += 1
        elif df['emotion'][i] == 4:
            img.save('train/sad/im'+str(sad)+'.png')
            sad += 1
        elif df['emotion'][i] == 5:
            img.save('train/surprised/im'+str(surprised)+'.png')
            surprised += 1
        elif df['emotion'][i] == 6:
            img.save('train/neutral/im'+str(neutral)+'.png')
            neutral += 1

    # test
    else:
        if df['emotion'][i] == 0:
            img.save('test/angry/im'+str(angry_test)+'.png')
            angry_test += 1
        elif df['emotion'][i] == 1:
            img.save('test/disgusted/im'+str(disgusted_test)+'.png')
            disgusted_test += 1
        elif df['emotion'][i] == 2:
            img.save('test/fearful/im'+str(fearful_test)+'.png')
            fearful_test += 1
        elif df['emotion'][i] == 3:
            img.save('test/happy/im'+str(happy_test)+'.png')
            happy_test += 1
        elif df['emotion'][i] == 4:
            img.save('test/sad/im'+str(sad_test)+'.png')
            sad_test += 1
        elif df['emotion'][i] == 5:
            img.save('test/surprised/im'+str(surprised_test)+'.png')
            surprised_test += 1
        elif df['emotion'][i] == 6:
            img.save('test/neutral/im'+str(neutral_test)+'.png')
            neutral_test += 1

print("Done!")

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# command line argument
ap = argparse.ArgumentParser()
ap.add_argument("--mode",help="train/display")
mode = ap.parse_args().mode

# %%
# plots accuracy and loss curves
def plot_model_history(model_history):
    """
    Plot Accuracy and Loss curves given the model_history
    """
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['accuracy'])+1),model_history.history['accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_accuracy'])+1),model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1),len(model_history.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    fig.savefig('plot.png')
    plt.show()
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# command line argument
ap = argparse.ArgumentParser()
ap.add_argument("--mode",help="train/display")
mode = ap.parse_args().mode
# Define data generators
train_dir = 'data/train'
val_dir = 'data/test'

num_train = 28709
num_val = 7178
batch_size = 64
num_epoch = 100

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])
model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=num_train // batch_size,
            epochs=num_epoch,
            validation_data=validation_generator,
            validation_steps=num_val // batch_size)
# Out:
# Epoch 1/100
# 349/350 [============================>.] - ETA: 0s - loss: 1.5779 - accuracy: 0.4388WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 250 batches). You may need to use the repeat() function when building your dataset.
# 350/350 [==============================] - 23s 64ms/step - loss: 1.5776 - accuracy: 0.4388 - val_loss: 3.5177 - val_accuracy: 0.1814
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/100
# 350/350 [==============================] - 17s 48ms/step - loss: 1.3827 - accuracy: 0.5134
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 3/100
# 350/350 [==============================] - 17s 47ms/step - loss: 1.2723 - accuracy: 0.5562
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 4/100
# 350/350 [==============================] - 17s 48ms/step - loss: 1.1875 - accuracy: 0.5851
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 5/100
# 350/350 [==============================] - 17s 47ms/step - loss: 1.1215 - accuracy: 0.6106
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 6/100
# 350/350 [==============================] - 17s 47ms/step - loss: 1.0554 - accuracy: 0.6352
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 7/100
# 350/350 [==============================] - 16s 47ms/step - loss: 1.0098 - accuracy: 0.6553
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 8/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.9602 - accuracy: 0.6709
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 9/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.9179 - accuracy: 0.6853
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 10/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.8832 - accuracy: 0.6953
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 11/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.8398 - accuracy: 0.7138
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 12/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.8073 - accuracy: 0.7257
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 13/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.7739 - accuracy: 0.7363
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 14/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.7422 - accuracy: 0.7493
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 15/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.7135 - accuracy: 0.7581
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 16/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.6800 - accuracy: 0.7701
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 17/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.6514 - accuracy: 0.7818
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 18/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.6283 - accuracy: 0.7892
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 19/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.6003 - accuracy: 0.7969
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 20/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.5741 - accuracy: 0.8075
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 21/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.5485 - accuracy: 0.8168
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 22/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.5317 - accuracy: 0.8209
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 23/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.5021 - accuracy: 0.8331
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 24/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.4844 - accuracy: 0.8402
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 25/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.4651 - accuracy: 0.8437
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 26/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.4496 - accuracy: 0.8526
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 27/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.4313 - accuracy: 0.8574
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 28/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.4150 - accuracy: 0.8626
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 29/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.4068 - accuracy: 0.8656
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 30/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3860 - accuracy: 0.8737
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 31/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.3720 - accuracy: 0.8777
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 32/100
# 350/350 [==============================] - 17s 49ms/step - loss: 0.3579 - accuracy: 0.8813
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 33/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3423 - accuracy: 0.8865
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 34/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3293 - accuracy: 0.8925
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 35/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.3170 - accuracy: 0.8947
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 36/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.3164 - accuracy: 0.8961
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 37/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.2975 - accuracy: 0.9024
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 38/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.2940 - accuracy: 0.9018
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 39/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.2810 - accuracy: 0.9066
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 40/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.2761 - accuracy: 0.9082
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 41/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.2545 - accuracy: 0.9160
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 42/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.2615 - accuracy: 0.9127
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 43/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.2458 - accuracy: 0.9181
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 44/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2399 - accuracy: 0.9203
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 45/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.2317 - accuracy: 0.9239
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 46/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.2283 - accuracy: 0.9251
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 47/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.2185 - accuracy: 0.9268
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 48/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.2083 - accuracy: 0.9305
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 49/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.2103 - accuracy: 0.9296
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 50/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.2022 - accuracy: 0.9336
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 51/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1999 - accuracy: 0.9345
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 52/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1861 - accuracy: 0.9392
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 53/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1870 - accuracy: 0.9377
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 54/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1883 - accuracy: 0.9381
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 55/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1792 - accuracy: 0.9413
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 56/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1818 - accuracy: 0.9384
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 57/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1753 - accuracy: 0.9411
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 58/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1711 - accuracy: 0.9444
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 59/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1620 - accuracy: 0.9465
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 60/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1573 - accuracy: 0.9474
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 61/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1608 - accuracy: 0.9463
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 62/100
# 350/350 [==============================] - 17s 49ms/step - loss: 0.1502 - accuracy: 0.9504
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 63/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1502 - accuracy: 0.9498
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 64/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1460 - accuracy: 0.9512
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 65/100
# 350/350 [==============================] - 17s 49ms/step - loss: 0.1379 - accuracy: 0.9524
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 66/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1361 - accuracy: 0.9540
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 67/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1383 - accuracy: 0.9541
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 68/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1327 - accuracy: 0.9557
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 69/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1333 - accuracy: 0.9565
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 70/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1300 - accuracy: 0.9566
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 71/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1289 - accuracy: 0.9565
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 72/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1271 - accuracy: 0.9575
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 73/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1282 - accuracy: 0.9570
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 74/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1212 - accuracy: 0.9596
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 75/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1189 - accuracy: 0.9605
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 76/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1131 - accuracy: 0.9616
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 77/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1120 - accuracy: 0.9629
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 78/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1179 - accuracy: 0.9599
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 79/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1129 - accuracy: 0.9632
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 80/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1075 - accuracy: 0.9641
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 81/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1024 - accuracy: 0.9661
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 82/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1047 - accuracy: 0.9657
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 83/100
# 350/350 [==============================] - 17s 48ms/step - loss: 0.1045 - accuracy: 0.9667
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 84/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1046 - accuracy: 0.9660
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 85/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.1026 - accuracy: 0.9659
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 86/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.1010 - accuracy: 0.9668
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 87/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0957 - accuracy: 0.9688
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 88/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.1025 - accuracy: 0.9656
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 89/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0952 - accuracy: 0.9686
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 90/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0956 - accuracy: 0.9673
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 91/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0966 - accuracy: 0.9682
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 92/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0966 - accuracy: 0.9677
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 93/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0895 - accuracy: 0.9710
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 94/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0882 - accuracy: 0.9713
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 95/100
# 350/350 [==============================] - 16s 46ms/step - loss: 0.0922 - accuracy: 0.9705
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 96/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0918 - accuracy: 0.9697
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 97/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.0844 - accuracy: 0.9730
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 98/100
# 350/350 [==============================] - 17s 47ms/step - loss: 0.0816 - accuracy: 0.9733
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 99/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0855 - accuracy: 0.9723
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# Epoch 100/100
# 350/350 [==============================] - 16s 47ms/step - loss: 0.0879 - accuracy: 0.9710
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr

# %%
#After successful training, we will visualize its performance.

import matplotlib.pyplot as plt
#Plotting the training and validation loss

f,ax=plt.subplots(2,1) #Creates 2 subplots under 1 column

#Assigning the first subplot to graph training loss and validation loss
ax[0].plot(model.history.history['loss'],color='b',label='Training Loss')
ax[0].plot(model.history.history['val_loss'],color='r',label='Validation Loss')

#Plotting the training accuracy and validation accuracy
ax[1].plot(model.history.history['accuracy'],color='b',label='Training  Accuracy')
ax[1].plot(model.history.history['val_accuracy'],color='r',label='Validation Accuracy')

plt.legend()

# %%
model.save_weights('model.h5')
